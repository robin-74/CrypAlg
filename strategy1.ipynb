# %%
# #start
# #step1 : 
# implement simple bol optimize to the maximum 
#     general 100 sets of args and see best combination with best args 
#     run monte carlos model Run numerous simulations to estimate the strategy’s robustness under different scenarios.


#     ml regression or more advna emodel to predict the future best args 
#     optimize more see wich market wokrs the best in voltiltit ycheck cov .... 
#     run live testing version
#     another version pair trading and add indication for mva and timeseries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
class CryptoData:
    def add_class(self, ticker, start, end):
        self.ticker = ticker
        self.start = start
        self.end = end
        self.data = self.init_data()
    
    def plot_data(self, df):
        plt.figure(figsize=(12, 6))
        sns.lineplot(x=df.index, y=df["Price"].squeeze(), label="Price")
        plt.title(f"{self.ticker} Price")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.show()

    def init_data(self):
        data1 = yf.download(self.ticker, self.start, self.end)
        df = data1[['Close']].copy()
        df.rename(columns={"Close": "Price"}, inplace=True)
        self.plot_data(df)
        return df

    def get_data(self):
        return self.data

    def set_sma(self):
        list_sma = []
        n = int(input("Enter how many SMA you want: "))
        for i in range(n):
            window = int(input(f"Enter SMA window size for SMA #{i+1}: "))
            list_sma.append(window)
        for window in list_sma:
            col_name = f"SMA_{window}"
            self.data[col_name] = self.data["Price"].rolling(window=window).mean()
        plt.figure(figsize=(12, 6))
        sns.lineplot(x=self.data.index, y=self.data["Price"].squeeze(), label="Price")
        for window in list_sma:
            col_name = f"SMA_{window}"
            sns.lineplot(x=self.data.index, y=self.data[col_name].squeeze(), label=col_name)
        plt.title(f"{self.ticker} Price with SMA(s)")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.show()

# %%
data_class = CryptoData()
data_class.add_class("BTC-USD", "2024-01-01", "2025-04-04")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_class.set_sma()
# Out:
# Enter how many SMA you want:  3
# Enter SMA window size for SMA #1:  20
# Enter SMA window size for SMA #2:  50
# Enter SMA window size for SMA #3:  60

# %%
#std 
#get the mean sum all of them / 3adadon 
#

# %%
#  np.random.seed(0)
# sns.set()
# uniform_data = np.random.rand(10, 12)
# ax = sns.heatmap(uniform_data, vmin=0, vmax=1)
# plt.show()

# %%
#HEATMAPS  :
